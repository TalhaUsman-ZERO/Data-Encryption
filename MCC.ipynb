# %%
#importing libraries
import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#tf.config.run_functions_eagerly(True)

# %%
#importing the dataset
dataset = pd.read_csv("preserved.csv", delimiter=",")
X = dataset.iloc[:,1:5].values
labelencoder=LabelEncoder()
y = labelencoder.fit_transform(dataset.iloc[:, 5].values)

# %%
#splitting the dataset
X_train, X_test, y_train , y_test=train_test_split(X,y,test_size=0.20, random_state=0)
X_train, X_validate, y_train , y_validate=train_test_split(X_train,y_train,test_size=0.20, random_state=0)

# %%
#feature Scaling
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_validate=sc.fit_transform(X_validate)
X_test=sc.transform(X_test)

# %%
# create model layers and Model

inputs = keras.Input(shape=(4,))

dense = layers.Dense(100, activation="relu",kernel_regularizer=keras.regularizers.l2(0.001))(inputs)
dense = layers.Dropout(0.25)(dense)
dense = layers.Dense(100, activation="relu",kernel_regularizer=keras.regularizers.l2(0.001))(dense)
dense = layers.Dropout(0.25)(dense)
dense = layers.Dense(100, activation="relu",kernel_regularizer=keras.regularizers.l2(0.001))(dense)
dense = layers.Dropout(0.25)(dense)

outputs = layers.Dense(3, activation="softmax")(dense)

model = keras.Model(inputs=inputs, outputs=outputs, name="Sequential_Model")

model.summary()


#adding the input layer and first hidden layer
#model.add(Dense(20, input_dim=4, activation='elu'))
#model.add(Dropout(0.25))

#adding the second hidden layer
#model.add(Dense(20, activation='elu'))
#model.add(Dropout(0.25))

#adding the output layer
#model.add(Dense(3, activation='softmax'))
# Out:
# Model: "Sequential_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_17 (InputLayer)        [(None, 4)]               0
# _________________________________________________________________
# dense_63 (Dense)             (None, 100)               500
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 100)               0
# ...

# %%
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) #optimizer='rmsprop'

# %%
# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
checkpoint.best = 0.7
callbacks_list = [checkpoint]

# %%
y_train = keras.utils.to_categorical(y_train, 3)
y_test = keras.utils.to_categorical(y_test, 3)
y_validate = keras.utils.to_categorical(y_validate, 3)

# %%
#fitting the model
history = model.fit(X_train, y_train,
          validation_data=(X_validate,y_validate),
          epochs=200,
          batch_size=2,
          callbacks=callbacks_list,
          verbose=1)
# Out:
# Epoch 1/200
# 50/50 [==============================] - 2s 11ms/step - loss: 1.3257 - accuracy: 0.4145 - val_loss: 1.2698 - val_accuracy: 0.3600
#
# Epoch 00001: val_accuracy did not improve from 0.70000
# Epoch 2/200
# 50/50 [==============================] - 0s 4ms/step - loss: 1.2647 - accuracy: 0.3696 - val_loss: 1.2621 - val_accuracy: 0.3200
#
# Epoch 00002: val_accuracy did not improve from 0.70000
# Epoch 3/200
# 50/50 [==============================] - 0s 4ms/step - loss: 1.2139 - accuracy: 0.4685 - val_loss: 1.2410 - val_accuracy: 0.3200
#
# Epoch 00003: val_accuracy did not improve from 0.70000
# Epoch 4/200
# 50/50 [==============================] - 0s 4ms/step - loss: 1.2299 - accuracy: 0.3984 - val_loss: 1.2424 - val_accuracy: 0.3600
#
# Epoch 00004: val_accuracy did not improve from 0.70000
# Epoch 5/200
# 50/50 [==============================] - 0s 4ms/step - loss: 1.1806 - accuracy: 0.4740 - val_loss: 1.2342 - val_accuracy: 0.3200
#
# ...

# %%
test_acc=model.evaluate(X_test,y_test)

print(test_acc)
# Out:
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7459 - accuracy: 0.2581
# [1.7459162473678589, 0.25806450843811035]
